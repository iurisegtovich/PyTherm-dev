# %%
# %matplotlib inline
#%matplotlib notebook

import numpy as numpy
from scipy.interpolate import griddata
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

table = numpy.loadtxt('delta V.txt', dtype='float', comments='#', converters=None,skiprows=0,usecols=None,unpack=False,ndmin=0)
V = table
table = numpy.loadtxt('meshgrid1.txt', dtype='float', comments='#', delimiter='	', converters=None,skiprows=0,usecols=None,unpack=False,ndmin=0)
X_grid = table
table = numpy.loadtxt('meshgrid2.txt', dtype='float', comments='#', delimiter='	', converters=None,skiprows=0,usecols=None,unpack=False,ndmin=0)
Y_grid = table
table = numpy.loadtxt('equilibrium_line.txt', dtype='float', comments='#', delimiter='	', converters=None,skiprows=0,usecols=None,unpack=False,ndmin=0)
T_eq = table[:,0]
P_eq = table[:,1]
table = numpy.loadtxt('calc_line.txt', dtype='float', comments='#', converters=None,skiprows=0,usecols=None,unpack=False,ndmin=0)
T_calc = table[:,0]
P_calc = table[:,1]


T0 = [273.15, 298.15]
P0 = [16661120.78, 28094614.64]

# %%
Ti, Pi = numpy.meshgrid( X_grid, Y_grid )

#print( Ti, Pi )
#print( T,P,V )

#def calcV(x_value,y_value,X,Y,Z):
#    tamanho1=len(x_value[0,:])
#    tamanho2=len(x_value[:,0])
#    Result = numpy.ones((tamanho2,tamanho1))     
#    for w in range (0,tamanho2):
#        for m in range (0,tamanho1):
#            i=0
#            while X[i] != x_value[w,m]:
#                i=i+1
#                while Y[i] != y_value[w,m]:
#                    i=i+1
#
#            Result[w,m] = Z[i]
#            
#    return Result
#    
#V_new = calcV(Ti, Pi, T, P, V)

# %%
def fmt(x, pos):
    a, b = '{:.2e}'.format(x).split('e')
    b = int(b)
    return r'${} \times 10^{{{}}}$'.format(a, b)

plt.figure()
Seq = [-6e-5, -4e-5, -2e-5, 0, 2e-5, 20e-5, 200e-5, 2000e-5]
colors = ['b','c','g', 'y', 'm', 'r', 'k']

CS = plt.contour(Ti, Pi, V, levels=Seq, colors=colors)
plt.clabel(CS, fontsize=9, inline=1, format=ticker.FuncFormatter(fmt))
plt.colorbar(format=ticker.FuncFormatter(fmt))
plt.semilogy()
plt.scatter(T_eq,P_eq)
plt.plot(T_calc,P_calc)

# %%
numpy.min(V)
# Out:
# -0.00039609406575983328

# %%
plt.figure()
CS = plt.contour(Ti, Pi, V, levels=[0], colors=['k'])
plt.clabel(CS, fontsize=9, inline=1, format=ticker.FuncFormatter(fmt))
plt.pcolor(Ti,Pi,V)
plt.semilogy()
plt.colorbar(format=ticker.FuncFormatter(fmt))
plt.show
plt.plot(T_eq,P_eq)
plt.plot(T_calc,P_calc)

# %%
plt.contour(Ti,Pi,V, Seq, colors=colors)
plt.plot(T_eq,P_eq)
plt.plot(T_calc,P_calc)
plt.semilogy()
# Out:
# []
